# %% [markdown]
# <a href="https://colab.research.google.com/github/ms624atyale/Exercise/blob/main/nlp_exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Tokenization

# %%
import nltk

# %%
txt = 'Here’s to the crazy ones, the misfits, the rebels, the troublemakers, the round pegs in the square holes. \
The ones who see things differently — they’re not fond of rules. \
You can quote them, disagree with them, glorify or vilify them, \
but the only thing you can’t do is ignore them because they change things. \
They push the human race forward, and while some may see them as the crazy ones, we see genius, \
because the ones who are crazy enough to think that they can change the world, are the ones who do.'

# %%
print(txt)
# Out:
# Here’s to the crazy ones, the misfits, the rebels, the troublemakers, the round pegs in the square holes. The ones who see things differently — they’re not fond of rules. You can quote them, disagree with them, glorify or vilify them, but the only thing you can’t do is ignore them because they change things. They push the human race forward, and while some may see them as the crazy ones, we see genius, because the ones who are crazy enough to think that they can change the world, are the ones who do.

# %%
file = open("crime_punishment.txt")
text = file.read().replace("\n", " ")
file.close()

# %%
# file = open("tmp.txt", "w")
# file.write(text)
# file.close()

# %%
txt.split()
# Out:
# ['Here’s',
#  'to',
#  'the',
#  'crazy',
#  'ones,',
#  'the',
#  'misfits,',
#  'the',
#  'rebels,',
#  'the',
#  'troublemakers,',
#  'the',
#  'round',
#  'pegs',
#  'in',
#  'the',
#  'square',
#  'holes.',
#  'The',
#  'ones',
#  'who',
#  'see',
#  'things',
#  'differently',
#  '—',
#  'they’re',
#  'not',
#  'fond',
#  'of',
#  'rules.',
#  'You',
#  'can',
#  'quote',
#  'them,',
#  'disagree',
#  'with',
#  'them,',
#  'glorify',
#  'or',
#  'vilify',
#  'them,',
#  'but',
#  'the',
#  'only',
#  'thing',
#  'you',
#  'can’t',
#  'do',
#  'is',
#  'ignore',
#  'them',
#  'because',
#  'they',
#  'change',
#  'things.',
#  'They',
#  'push',
#  'the',
#  'human',
#  'race',
#  'forward,',
#  'and',
#  'while',
#  'some',
#  'may',
#  'see',
#  'them',
#  'as',
#  'the',
#  'crazy',
#  'ones,',
#  'we',
#  'see',
#  'genius,',
#  'because',
#  'the',
#  'ones',
#  'who',
#  'are',
#  'crazy',
#  'enough',
#  'to',
#  'think',
#  'that',
#  'they',
#  'can',
#  'change',
# ...

# %%
' '.join(txt.split())
# Out:
# 'Here’s to the crazy ones, the misfits, the rebels, the troublemakers, the round pegs in the square holes. The ones who see things differently — they’re not fond of rules. You can quote them, disagree with them, glorify or vilify them, but the only thing you can’t do is ignore them because they change things. They push the human race forward, and while some may see them as the crazy ones, we see genius, because the ones who are crazy enough to think that they can change the world, are the ones who do.'

# %%
import nltk

# %%
from nltk.tokenize import word_tokenize
nltk.download('punkt')
words = word_tokenize(txt)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
from nltk.tokenize import RegexpTokenizer
retokenize = RegexpTokenizer("[\w]+")
words = retokenize.tokenize(txt)

# %%
words
# Out:
# ['Here',
#  's',
#  'to',
#  'the',
#  'crazy',
#  'ones',
#  'the',
#  'misfits',
#  'the',
#  'rebels',
#  'the',
#  'troublemakers',
#  'the',
#  'round',
#  'pegs',
#  'in',
#  'the',
#  'square',
#  'holes',
#  'The',
#  'ones',
#  'who',
#  'see',
#  'things',
#  'differently',
#  'they',
#  're',
#  'not',
#  'fond',
#  'of',
#  'rules',
#  'You',
#  'can',
#  'quote',
#  'them',
#  'disagree',
#  'with',
#  'them',
#  'glorify',
#  'or',
#  'vilify',
#  'them',
#  'but',
#  'the',
#  'only',
#  'thing',
#  'you',
#  'can',
#  't',
#  'do',
#  'is',
#  'ignore',
#  'them',
#  'because',
#  'they',
#  'change',
#  'things',
#  'They',
#  'push',
#  'the',
#  'human',
#  'race',
#  'forward',
#  'and',
#  'while',
#  'some',
#  'may',
#  'see',
#  'them',
#  'as',
#  'the',
#  'crazy',
#  'ones',
#  'we',
#  'see',
#  'genius',
#  'because',
#  'the',
#  'ones',
#  'who',
#  'are',
#  'crazy',
#  'enough',
#  'to',
#  'think',
#  'that',
#  'they',
#  'can',
#  'change',
# ...

# %% [markdown]
# ### Normalization
# Stemming: am → am, the going → the go, having → hav
# Lemmatization: am → be, the going → the going, having → have

# %%
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()
[stemmer.stem(w) for w in words] # words 로 list comprehension. 이 워즈에서 하나하나씩 루프를 도는데, 단어를 w 에 담아서, 앞에 stemmer.stem () 함수가 실행된다. 어떤 함수는 어떤 장/단점이 있구나.
# Out:
# ['here',
#  's',
#  'to',
#  'the',
#  'crazi',
#  'one',
#  'the',
#  'misfit',
#  'the',
#  'rebel',
#  'the',
#  'troublemak',
#  'the',
#  'round',
#  'peg',
#  'in',
#  'the',
#  'squar',
#  'hole',
#  'the',
#  'one',
#  'who',
#  'see',
#  'thing',
#  'differ',
#  'they',
#  're',
#  'not',
#  'fond',
#  'of',
#  'rule',
#  'you',
#  'can',
#  'quot',
#  'them',
#  'disagre',
#  'with',
#  'them',
#  'glorifi',
#  'or',
#  'vilifi',
#  'them',
#  'but',
#  'the',
#  'onli',
#  'thing',
#  'you',
#  'can',
#  't',
#  'do',
#  'is',
#  'ignor',
#  'them',
#  'becaus',
#  'they',
#  'chang',
#  'thing',
#  'they',
#  'push',
#  'the',
#  'human',
#  'race',
#  'forward',
#  'and',
#  'while',
#  'some',
#  'may',
#  'see',
#  'them',
#  'as',
#  'the',
#  'crazi',
#  'one',
#  'we',
#  'see',
#  'geniu',
#  'becaus',
#  'the',
#  'one',
#  'who',
#  'are',
#  'crazi',
#  'enough',
#  'to',
#  'think',
#  'that',
#  'they',
#  'can',
#  'chang',
#  'the',
#  'world',
#  'are',
# ...

# %%
from nltk.stem import LancasterStemmer
stemmer = LancasterStemmer()
[stemmer.stem(w) for w in words]

# %%
from nltk.stem import WordNetLemmatizer # 활용을 복원하여 단어를 추출해줌. 
nltk.download('wordnet')
lemmatizer = WordNetLemmatizer()
[lemmatizer.lemmatize(w) for w in words]
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# ['Here',
#  's',
#  'to',
#  'the',
#  'crazy',
#  'one',
#  'the',
#  'misfit',
#  'the',
#  'rebel',
#  'the',
#  'troublemaker',
#  'the',
#  'round',
#  'peg',
#  'in',
#  'the',
#  'square',
#  'hole',
#  'The',
#  'one',
#  'who',
#  'see',
#  'thing',
#  'differently',
#  'they',
#  're',
#  'not',
#  'fond',
#  'of',
#  'rule',
#  'You',
#  'can',
#  'quote',
#  'them',
#  'disagree',
#  'with',
#  'them',
#  'glorify',
#  'or',
#  'vilify',
#  'them',
#  'but',
#  'the',
#  'only',
#  'thing',
#  'you',
#  'can',
#  't',
#  'do',
#  'is',
#  'ignore',
#  'them',
#  'because',
#  'they',
#  'change',
#  'thing',
#  'They',
#  'push',
#  'the',
#  'human',
#  'race',
#  'forward',
#  'and',
#  'while',
#  'some',
#  'may',
#  'see',
#  'them',
#  'a',
#  'the',
#  'crazy',
#  'one',
#  'we',
#  'see',
#  'genius',
#  'because',
#  'the',
#  'one',
#  'who',
#  'are',
# ...

# %% [markdown]
# ### Stopword

# %%
from nltk.corpus import stopwords  
nltk.download('stopwords') #필요한 패키지라서 따로 다운로드 함.
print(words)
words = [w for w in words if not w in stopwords.words('english')] # 만양 워드가 스탑워즈에 포함되지 않는다면 이걸 하나씩 체크하고 이걸 워드에 00 해라???
print(words)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ...

# %% [markdown]
# ### Collocation, Concordance

# %%
nltk.download('gutenberg')
text = nltk.corpus.gutenberg.raw('austen-emma.txt')
words = retokenize.tokenize(text)
# Out:
# [nltk_data] Downloading package gutenberg to /root/nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!

# %%
nltk.Text(words).collocations()
# Out:
# Mrs Weston; Frank Churchill; Miss Woodhouse; Mrs Elton; Miss Bates;
# Jane Fairfax; Miss Fairfax; every thing; young man; every body; great
# deal; Mrs Goddard; dare say; Maple Grove; John Knightley; Miss Taylor;
# Miss Smith; Robert Martin; Colonel Campbell; Box Hill

# %%
nltk.Text(words).concordance('Emma', 79, 10) # 엠마를 중심으로 양옆으로 79 캐릭터를 넣어서 총 10개의 예문을 끄집어 내라.
#교육적으로 유용함.
# Out:
# Displaying 10 of 865 matches:
#                                      Emma by Jane Austen 1816 VOLUME I CHAPTER
#                                      Emma Woodhouse handsome clever and rich w
# f both daughters but particularly of Emma Between _them_ it was more the intim
# nd friend very mutually attached and Emma doing just what she liked highly est
#  by her own The real evils indeed of Emma s situation were the power of having
# ding day of this beloved friend that Emma first sat in mournful thought of any
# going only half a mile from them but Emma was aware that great must be the dif
# a day It was a melancholy change and Emma could not but sigh over it and wish
# ll the rest of her life at Hartfield Emma smiled and chatted as cheerfully as
# l be able to tell her how we all are Emma spared no exertions to maintain this

# %%
nltk.Text(words).dispersion_plot(["Emma", "Knightley", "Frank", "Jane", "Harriet", "Robert"])
#16만 00 에서 위에 지정한 사람이름만 나온 것을 시간상으로 플랏하는 것이다.

# %%
nltk.Text(words).similar("Emma") # 엠마가 등장하는 하는 것과 비슷한 위치에 나오는 단어들
# Out:
# she it he i harriet you her jane him that me and all they them herself
# there but be isabella

# %%
nltk.Text(words).common_contexts(["Emma", "she"]) #엠마와 she 가 동시에 나올 수 있는 콘텍스트 찾아봐라
# Out:
# but_was and_could that_should said_and which_could whom_knew
# which_particularly and_imagined that_could said_i that_began
# and_thought do_was but_could than_had said_but manner_was this_could
# as_saw possible_could

# %% [markdown]
# ### Frequency distribution, Frequency plot

# %%
fd = nltk.FreqDist(words).most_common(20) #가장 자주 등장하는 20 단어 찾아라
fd
# Out:
# [('to', 5183),
#  ('the', 4844),
#  ('and', 4672),
#  ('of', 4279),
#  ('I', 3178),
#  ('a', 3004),
#  ('was', 2385),
#  ('her', 2381),
#  ('it', 2128),
#  ('in', 2118),
#  ('not', 2101),
#  ('be', 1970),
#  ('she', 1778),
#  ('that', 1730),
#  ('you', 1677),
#  ('had', 1606),
#  ('as', 1387),
#  ('he', 1365),
#  ('for', 1321),
#  ('have', 1301)]

# %%
nltk.Text(words).plot(20) # 가장 자주 등장하는 20 단어를 플랏해라.

# %% [markdown]
# ### Dictionary

# %%
nltk.download('words') # nltk 영어사전 다운로드ㄷㅇ
#ed = nltk.corpus.words.words('en')
nltk.corpus.words.words('en')[-20:-1]

# %%
len(nltk.corpus.words.words('en'))
# Out:
# 235886

# %% [markdown]
# ### Regular expression

# %%
import re #regular expression import 하기, 아래에서 왜하는지 , 어떻게 하는지 보자.

# %%
'''       Basic Regular Expression Meta-Characters, Including Wildcards, Ranges and Closures

.	        Wildcard, matches any character
^abc	    Matches some pattern abc at the start of a string
abc$	    Matches some pattern abc at the end of a string
[abc]	    Matches one of a set of characters
[^abc]    Matches anything but a set of characters
[A-Z0-9]	Matches one of a range of characters
ed|ing|s	Matches one of the specified strings (disjunction)
*	        Zero or more of previous item, e.g. a*, [a-z]* (also known as Kleene Closure)
+	        One or more of previous item, e.g. a+, [a-z]+
?	        Zero or one of the previous item (i.e. optional), e.g. a?, [a-z]?
{n}	      Exactly n repeats where n is a non-negative integer
{n,}	    At least n repeats
{,n}	    No more than n repeats
{m,n}	    At least m and no more than n repeats
a(b|c)+	  Parentheses that indicate the scope of the operators
(...)     Matches whatever regular expression is inside the parentheses
\d
Matches any decimal digit; this is equivalent to the class [0-9].
\D
Matches any non-digit character; this is equivalent to the class [^0-9].
\s
Matches any whitespace character; this is equivalent to the class [ \t\n\r\f\v].
\S
Matches any non-whitespace character; this is equivalent to the class [^ \t\n\r\f\v].
\w
Matches any alphanumeric character; this is equivalent to the class [a-zA-Z0-9_].
\W
Matches any non-alphanumeric character; this is equivalent to the class [^a-zA-Z0-9_].

'''

# %%
import nltk
nltk.download('words')
engdict = nltk.corpus.words.words('en')
result = [w for w in engdict if re.search('ed$', w)] #24만개 영어 리스트에서 (포 루프 24만번), 제일 첫번째거부터 w 로 받음. 그다음 if 절로 들어감. w에 단어나 뭐가 들어가서 'ed$' (스트링(단어)의 끝에 ed 가 있으면) (혹은 '^pro' (시작을 pro로 하면); 'ing$')에서를 찾아서 list up 해서 Result 로 보내라. 이걸 적을 수 있으면 여러분이 정규표현식을 자유롭게 사용할 수 있다는 것이다. 
# result = [w for w in engdict if re.search('^..j..t..$', w)] 아무 케릭터로 시자하여 2개 나오고 j 나오고 또 아무 케릭터 2 다음 t 다음 아무 케릭터 두개 나오고 단어 끝나는 단어 찾아라 
# result = [w for w in engdict if re.search('^[ghi][mno][jlk][def]$', w)] #[[] #대괄호 000 세개 중에 1개] #re (Regular Expression)은 우리가 상상하는 모든 것을 할 수 있다. 
# result = [w for w in engdict if re.search('^[ah]+$', w)][:10] #a 혹은 h 시작하여 하나이상 나오고 끝나는 것을 찾아라.
print(result[:10]) #결과 중 10개만 보여다오.
# Out:
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-9d4fcef3c52c> in <module>()
#       2 nltk.download('words')
#       3 engdict = nltk.corpus.words.words('en')
# ----> 4 result = [w for w in engdict if re.search('ed$', w)] #24만개 영어 리스트에서 (포 루프 24만번), 제일 첫번째거부터 w 로 받음. 그다음 if 절로 들어감. w에 단어나 뭐가 들어가서 'ed$' (스트링(단어)의 끝에 ed 가 있으면) (혹은 '^pro' (시작을 pro로 하면); 'ing$')에서를 찾아서 list up 해서 Result 로 보내라. 이걸 적을 수 있으면 여러분이 정규표현식을 자유롭게 사용할 수 있다는 것이다.
#       5 # result = [w for w in engdict if re.search('^..j..t..$', w)] 아무 케릭터로 시자하여 2개 나오고 j 나오고 또 아무 케릭터 2 다음 t 다음 아무 케릭터 두개 나오고 단어 끝나는 단어 찾아라
#       6 # result = [w for w in engdict if re.search('^[ghi][mno][jlk][def]$', w)]
#
# <ipython-input-41-9d4fcef3c52c> in <listcomp>(.0)
#       2 nltk.download('words')
# ...

# %%
nltk.download('treebank') # 월스트리트 저널 받은 것 다운로드 
wsj = nltk.corpus.treebank.words() # 사전보다 지저분. 숫자 등등 더 지저분하게 되어있음. 

result = [w for w in wsj if re.search('(ed|ing)$', w)] #ed 로 끝나던지 ing로 끝나거나 하는 것 다 찾아라
# result = [w for w in wsj if re.search('^[0-9]+\.[0-9]+$', w)] # 숫자가 하나 이상 + 나오고 (캐릭터의 세트 0-9), (. 만 찍으면 any character 이걸 구분하기 위해서 \. 로 적음) 소수점 있는 숫자 찾아라.
# result = [w for w in wsj if re.search('^[A-Z]+\$$', w)] # 대문자 달러 나오는 거 찾아라
# result = [w for w in wsj if re.search('^[0-9]{4}$', w)] # 숫자가 4개 나와라 ({4} {} 는 횟수에 대한 명칭) 이거 찾아라
# result = [w for w in wsj if re.search('^[0-9]+-[a-z]{3,5}$', w)] # 숫자로 시작하여 소문자가 3~5개 사이로 나오는 거 찾아라
# result = [w for w in wsj if re.search('^[a-z]{5,}-[a-z]{2,3}-[a-z]{,6}$', w)] # 소문자가 5번 나오고 하이픈 나오고 소문자가 2번에서 3번 나오고 하이픈 나오고 소문자가 6개 나오는 단어 찾아라.

result = sorted(set(result))
print(result[:10])
# Out:
# [nltk_data] Downloading package treebank to /root/nltk_data...
# [nltk_data]   Package treebank is already up-to-date!
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-04c7e384fba3> in <module>()
#       2 wsj = nltk.corpus.treebank.words() # 사전보다 지저분. 숫자 등등 더 지저분하게 되어있음.
#       3
# ----> 4 result = [w for w in wsj if re.search('(ed|ing)$', w)] #ed 로 끝나던지 ing로 끝나거나 하는 것 다 찾아라
#       5 # result = [w for w in wsj if re.search('^[0-9]+\.[0-9]+$', w)] # 숫자가 하나 이상 + 나오고 (캐릭터의 세트 0-9), (. 만 찍으면 any character 이걸 구분하기 위해서 \. 로 적음) 소수점 있는 숫자 찾아라.
#       6 # result = [w for w in wsj if re.search('^[A-Z]+\$$', w)] # 대문자 달러 나오는 거 찾아라
#
# <ipython-input-43-04c7e384fba3> in <listcomp>(.0)
#       2 wsj = nltk.corpus.treebank.words() # 사전보다 지저분. 숫자 등등 더 지저분하게 되어있음.
#       3
# ----> 4 result = [w for w in wsj if re.search('(ed|ing)$', w)] #ed 로 끝나던지 ing로 끝나거나 하는 것 다 찾아라
# ...

# %% [markdown]
# ### Extract information (pos tag, named entity)

# %%
sent = "I am Jhon from America and would like to go to Starbuck"
words = nltk.word_tokenize(sent)

# %%
'''
POS tag list:

CC	coordinating conjunction
CD	cardinal digit
DT	determiner
EX	existential there (like: "there is" ... think of it like "there exists")
FW	foreign word
IN	preposition/subordinating conjunction
JJ	adjective	'big'
JJR	adjective, comparative	'bigger'
JJS	adjective, superlative	'biggest'
LS	list marker	1)
MD	modal	could, will
NN	noun, singular 'desk'
NNS	noun plural	'desks'
NNP	proper noun, singular	'Harrison'
NNPS	proper noun, plural	'Americans'
PDT	predeterminer	'all the kids'
POS	possessive ending	parent's
PRP	personal pronoun	I, he, she
PRP$	possessive pronoun	my, his, hers
RB	adverb	very, silently,
RBR	adverb, comparative	better
RBS	adverb, superlative	best
RP	particle	give up
TO	to	go 'to' the store.
UH	interjection	errrrrrrrm
VB	verb, base form	take
VBD	verb, past tense	took
VBG	verb, gerund/present participle	taking
VBN	verb, past participle	taken
VBP	verb, sing. present, non-3d	take
VBZ	verb, 3rd person sing. present	takes
WDT	wh-determiner	which
WP	wh-pronoun	who, what
WP$	possessive wh-pronoun	whose
WRB	wh-abverb	where, when
'''

# %%
nltk.download('averaged_perceptron_tagger')
pos = nltk.pos_tag(words)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.

# %%
pos
# Out:
# [('I', 'PRP'),
#  ('am', 'VBP'),
#  ('Jhon', 'RB'),
#  ('from', 'IN'),
#  ('America', 'NNP'),
#  ('and', 'CC'),
#  ('would', 'MD'),
#  ('like', 'VB'),
#  ('to', 'TO'),
#  ('go', 'VB'),
#  ('to', 'TO'),
#  ('Starbuck', 'NNP')]

# %%
nltk.download('maxent_ne_chunker') # 추가 정보 주는 것
NE = nltk.ne_chunk(pos)
# common Entity types: ORGANIZATION, PERSON, LOCATION, DATE, TIME, MONEY, and GPE (geo-political entity)
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!

# %%
NE
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     336             method = get_real_method(obj, self.print_method)
#     337             if method is not None:
# --> 338                 return method()
#     339             return None
#     340         else:
#
# /usr/local/lib/python3.7/dist-packages/nltk/tree.py in _repr_png_(self)
#     717         from nltk.draw.util import CanvasFrame
#     718         from nltk.internals import find_binary
# --> 719         _canvas_frame = CanvasFrame()
#     720         widget = tree_to_treesegment(_canvas_frame.canvas(), self)
#     721         _canvas_frame.add_widget(widget)
#
# /usr/local/lib/python3.7/dist-packages/nltk/draw/util.py in __init__(self, parent, **kw)
#    1651         # If no parent was given, set up a top-level window.
# ...

# %% [markdown]
# ### Wordcloud

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

text = nltk.corpus.gutenberg.raw('bible-kjv.txt') #텍스트 공짜 코퍼스 사용하기 (다른 방법은 직접 타이핑, 또 다른 방법은 파일에 업로드 후 불러오기)

wc = WordCloud().generate(text) 
plt.imshow(wc)

# %%
stopwords = set(STOPWORDS) 
stopwords.add('unto') #스탑워드에 unto 빼고 플랏
wc = WordCloud(stopwords = stopwords).generate(text) 
plt.imshow(wc)
